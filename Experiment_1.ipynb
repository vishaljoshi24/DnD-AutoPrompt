# %% [markdown]
# <a href="https://colab.research.google.com/github/vishaljoshi24/DungeonsAndDragonsTurnClassification/blob/Codex-Branch/Experiment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone -b Codex-Branch https://github.com/vishaljoshi24/DungeonsAndDragonsTurnClassification/
# %cd /content/DungeonsAndDragonsTurnClassification
# Out:
# fatal: destination path 'DungeonsAndDragonsTurnClassification' already exists and is not an empty directory.
# /content/DungeonsAndDragonsTurnClassification

# %%
# !pip install dspy==3.2.1
# Out:
# Requirement already satisfied: dspy in /usr/local/lib/python3.12/dist-packages (3.2.1)
# Requirement already satisfied: openai>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.45.0)
# Requirement already satisfied: regex>=2023.10.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (2025.11.3)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.11.9)
# Requirement already satisfied: tqdm>=4.66.1 in /usr/local/lib/python3.12/dist-packages (from dspy) (4.67.3)
# Requirement already satisfied: requests>=2.31.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.32.4)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.13.4)
# Requirement already satisfied: litellm>=1.64.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (1.93.0)
# Requirement already satisfied: diskcache>=5.6.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (5.6.3)
# Requirement already satisfied: json-repair>=0.54.2 in /usr/local/lib/python3.12/dist-packages (from dspy) (0.61.7)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (9.1.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from dspy) (4.14.2)
# Requirement already satisfied: asyncer==0.0.8 in /usr/local/lib/python3.12/dist-packages (from dspy) (0.0.8)
# Requirement already satisfied: cachetools>=5.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (6.2.6)
# Requirement already satisfied: cloudpickle>=3.1.2 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.1.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (2.0.2)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from dspy) (3.8.1)
# Requirement already satisfied: gepa==0.0.27 in /usr/local/lib/python3.12/dist-packages (from gepa[dspy]==0.0.27->dspy) (0.0.27)
# Requirement already satisfied: typeguard==4.4.3 in /usr/local/lib/python3.12/dist-packages (from dspy) (4.4.3)
# Requirement already satisfied: typing_extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from typeguard==4.4.3->dspy) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio->dspy) (3.18)
# Requirement already satisfied: fastuuid<1.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.14.0)
# Requirement already satisfied: httpx<1.0,>=0.28.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.28.1)
# Requirement already satisfied: python-dotenv<2.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (1.2.2)
# Requirement already satisfied: tiktoken<1.0,>=0.8.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.13.0)
# Requirement already satisfied: importlib-metadata<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (8.9.0)
# Requirement already satisfied: tokenizers<1.0,>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (0.22.2)
# Requirement already satisfied: click<9.0,>=8.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (8.4.2)
# Requirement already satisfied: jinja2<4.0,>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (3.1.6)
# Requirement already satisfied: aiohttp<4.0,>=3.10 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (3.14.1)
# Requirement already satisfied: jsonschema<5.0,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from litellm>=1.64.0->dspy) (4.26.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (0.16.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai>=0.28.1->dspy) (1.3.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.0->dspy) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31.0->dspy) (2026.6.17)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0,>=3.10->litellm>=1.64.0->dspy) (1.24.2)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0,>=0.28.0->litellm>=1.64.0->dspy) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0,>=0.28.0->litellm>=1.64.0->dspy) (0.16.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<9.0,>=8.0.0->litellm>=1.64.0->dspy) (4.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2<4.0,>=3.1.6->litellm>=1.64.0->dspy) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema<5.0,>=4.0.0->litellm>=1.64.0->dspy) (2026.6.3)
# Requirement already satisfied: huggingface-hub<2.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (1.23.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (3.29.7)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (1.5.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=0.16.4->tokenizers<1.0,>=0.21.0->litellm>=1.64.0->dspy) (6.0.3)

# %%
import argparse

# %%
from modules import(
    AgentProfile,
    BaselineConversation,
    configure_lm,
    BaselineChatbot
)

# %%
RAT_INFESTATION_SCENARIO = (
'This D&D short scenario specifically concerns a rat infestation. '
'It is set in a craft brewery and is in dire need of help. '
'The players in this scenario are Alice and Bob.'
'The non-player character is Charlie, and he is controlled by the Dungeon Master. '
'Alice and Bob are here to sort out a RAT INFESTATION in the brewery\'s BASEMENT. '
'For the duration of the scenario, only Alice, Bob and the brewery owner Charlie are in the brewery '
'At the beginning of this adventure Alice and Bob '
'meet in the main taproom of the brewery. These two adventurers '
'DO NOT know each other AT FIRST and need to get to know each other. '
'Charlie hands out pints of Ale to Alice and Bob as they get to know each other. '
'Alice and Bob should start by asking Charlie for some information about the infestation. '
'Alice and Bob should then come up with a strategy for clearing out the infestation. '
'Finally, Alice and Bob should explore the brewery\'s cellar based on their strategy. '
'The scenario ends before players start combat. '
)

MISSING_CHILD_SCENARIO = (
  'This D&D short campaign specifically concerns Diana, a magical walrus who has brought a group of animals to safety. '
  'She has brought the animals to the mountains, hoping to protect them from being used by an evil druid to wreak havoc on the local area. '
  'She requests the help of Alice and Bob to stem the threats against everyone. '
  'For the duration of this scenario, only Alice, Bob and Diana are in a cave in the mountains. '
  'At the beginning of this adventure Alice and Bob '
  'meet Diana at her cave in the mountains. The three adventurers '
  'DO NOT know each other AT FIRST and need to get to know each other.'
  'The cave in which the three characters meet has a river which flows out to the open air. '
  'Diana asks Alice and Bob to find her child, an awakened otter that has been spying on a nearby city. '
  'Alice and Bob should start by asking Diana some questions about the missing child. '
  'Alice and Bob should then come up with a strategy for their search of the child. '
  'Finally, Alice and Bob should explore the surrounding mountains based on their strategy. '
)

# %%
def build_conversation() -> BaselineConversation:
    alice = AgentProfile(
        name="Alice",
        character="Alice, a dwarf barbarian.",
        instructions=(
        'The instructions for how to play the role of a D&D player are as '
        'follows. This is a short scenario in which you '
        f'play the role of a character named Alice. This scenario '
        'is structured as a Dungeons & Dragons game. '
        'The goal is to be consistent, but creative. It is '
        'important to play the role of a Dungeons & Dragons player as '
        'accurately as possible, i.e., by responding in ways that you think '
        'it is likely a player would respond, and taking '
        'into account all information that you have. '
        'It is important that you collaborate with the  '
        'other player, on the task at hand and listen to the Dungeon Master\'s '
        'insturctions.'
        'Do not be verbose. '
        'Do not repeat yourself. '
        'Always use first-person limited perspective.'
        ),
        inventory = [
                "One set of common clothes",
                "Two daggers",
                "One axe",
                "50 feet of rope",
                "One tinderbox",
                "One torch",
            ],
        abilities = {""},
        skills = {""},
    )
    bob = AgentProfile(
        name="Bob",
        character="Bob, a wizard.",
        instructions=(
        'The instructions for how to play the role of a D&D player are as '
        'follows. This is a short scenario in which you '
        'play the role of a character named Bob. This scenario '
        'is structured as a Dungeons & Dragons game. '
        'The goal is to be consistent, but creative. It is '
        'important to play the role of a Dungeons & Dragons player as '
        'accurately as possible, i.e., by responding in ways that you think '
        'it is likely a player would respond, and taking '
        'into account all information that you have. '
        'It is important that you collaborate with the  '
        'other player, on the task at hand and listen to the Dungeon Master\'s '
        'insturctions.'
        'Do not be verbose. '
        'Do not repeat yourself. '
        'Always use first-person limited perspective.'
        ),
        inventory = [
                "One Wizard's Staff",
                "One can of oil",
                "One tinderbox",
                "Thunderwave spell: You unleash a wave of thunderous energy.",
                "Command spell: You speak a one-word command to a creature you can see within range."
            ],
        abilities = {""},
        skills = {""},
    )
    dungeon_master = AgentProfile(
          name="Dungeon Master",
          character="The Dungeon Master, who also plays the role of Charlie: the owner of the Wizards Tower Brewing Company.",
          instructions= (
          'This is a tabletop role-playing game: Dungeons & Dragons. You are the Dungeon Master.'
          'You will describe the current situation to the players in the game and then on the basis '
          'of what you tell them they will suggest actions for the character they control. '
          'You will then decide if the action is valid based on Dungeons & Dragons 5th Edition rules. '
          'Aside from you, each other player controls just one character. '
          'If any of the players deviates dramatically from the scenario your response should attempt to re-orient the scenario. '
          'You are the Dungeon Master so you control any non-player characters or adversaries. '
          'You can answer player\'s questions and give them any items they need, but you should '
          'not get involved with the task directly. '
          'You will track the state of the world and keep it consistent as time  '
          'passes in the simulation and the players take actions and change things in their world. '
          'Remember that this is a game. It should be fun for the players. '
          'You should use second-person perspective, when speaking directly to the players. '
          'You should use first-person limited perspective when role-playing as non-player characters and adversaries.'
          'Do not be verbose. Do not repeat yourself.'
          ),
          inventory = [""],
          abilities = {""},
          skills = {""},
    )

    return BaselineConversation(
        agent_a=alice,
        agent_b=bob,
        agent_c=dungeon_master,
        scenario=RAT_INFESTATION_SCENARIO,
        chatbot_a=BaselineChatbot(),
        chatbot_b=BaselineChatbot(),
        chatbot_c=BaselineChatbot()
    )

# %%
parser = argparse.ArgumentParser(description="Run three D&D DSPy agents together.")

# %%
parser.add_argument(
    "--opening-message",
    default="You find yourselves in the main taproom of the brewery, questioning Charlie the brewery owner.",
    help="The first turn spoken by the Dungeon Master.",
)
# Out:
# _StoreAction(option_strings=['--opening-message'], dest='opening_message', nargs=None, const=None, default='You find yourselves in the main taproom of the brewery, questioning Charlie the brewery owner.', type=None, choices=None, required=False, help='The first turn spoken by the Dungeon Master.', metavar=None)

# %%
parser.add_argument(
    "--rounds",
    type=int,
    default=15,
    help="Number of replies to generate after the opening message.",
)
# Out:
# _StoreAction(option_strings=['--rounds'], dest='rounds', nargs=None, const=None, default=15, type=<class 'int'>, choices=None, required=False, help='Number of replies to generate after the opening message.', metavar=None)

# %%
parser.add_argument("--model", default="ollama_chat/qwen3:8b")
# Out:
# _StoreAction(option_strings=['--model'], dest='model', nargs=None, const=None, default='ollama_chat/qwen3:8b', type=None, choices=None, required=False, help=None, metavar=None)

# %%
parser.add_argument("--api-base", default="http://localhost:11434")
# Out:
# _StoreAction(option_strings=['--api-base'], dest='api_base', nargs=None, const=None, default='http://localhost:11434', type=None, choices=None, required=False, help=None, metavar=None)

# %%
args = parser.parse_args([])

# %%
configure_lm(model=args.model, api_base=args.api_base)

# %%
conversation = build_conversation()

# %%
for turn in conversation.run(args.opening_message, rounds=args.rounds):
    print(turn)
# Out:
# Dungeon Master: You find yourselves in the main taproom of the brewery, questioning Charlie the brewery owner.
# Alice: “Charlie, where’s the worst of the rat trouble? We’ll need to clear a path. My axe’s good for smashing through nests—what’s your plan?”
# Bob: "I’ll handle the bulk with Thunderwave. You take the nest, I’ll clear the tunnels."
# Dungeon Master: The cellar’s tunnels are narrow and maze-like, with debris from past collapses. Your plan could work—Thunderwave might dislodge rats from their hiding places. But be warned: the air smells of damp rot, and the floor groans underfoot. Where do you want to start?
# Alice: “East tunnel—smells worse there. I’ll break through the debris. You ready when I am.”
# Bob: Ready when you are. Thunderwave will clear the path once you’re through.
# Dungeon Master: The debris gives way with a wet crunch, sending a shower of dust into the air. A low, guttural screech echoes as rats scatter—some fleeing, others diving into unseen crevices. The tunnel ahead grows darker, but the stench of rot intensifies. Do you press forward or check the other tunnels?
# Alice: "Let’s move. Axe first, then torch. I’ll clear a path."
# Bob: "Thunderwave, now."
# Dungeon Master: The thunderclap rattles the tunnel, scattering rats into the walls. A few screech before silence falls—then a deeper, guttural growl echoes from deeper in the basement. The dust swirls, blinding you for a moment.
# Alice: "Keep your eyes on the growl. I’ll clear the dust—axe first, then torch."
# Bob: "Command! Make them attack the growl!"
# Dungeon Master: The growl erupts into a monstrous snarl as a hulking rat king slithers from the darkness, its many limbs twitching. Rats swarm around its base, gnawing at its underbelly. "Now!" you shout, thrusting your axe into the fray. The rat king lunges, its fangs snapping inches from your face. What do you do?
# Alice: Parry the bite! Slash its flank with the axe!
# Bob: Thunderwave!
# Dungeon Master: The thunderwave rattles the cellar, knocking the rat king back as its swarm of underlings scatters. "Now!" you shout, eyes darting between the two adventurers. "What's your move?"

# %%
import dspy
dspy.inspect_history(n=10)
