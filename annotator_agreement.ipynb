# %% [markdown]
# <a href="https://colab.research.google.com/github/vishaljoshi24/DungeonsAndDragonsTurnClassification/blob/main/annotator_agreement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import sklearn

# %%
data = pd.read_excel('')

# %%
data

# %%
labels_1 = []
labels_2 = []

for i in range(len(data)):
  labels_1.append(data[][i])
  labels_2.append(data[][i])

# %%
len(labels_1)

# %%
len(labels_2)

# %%
from sklearn.metrics import cohen_kappa_score

cohen_kappa_score(labels_1, labels_2)
