# %% [markdown]
# <a href="https://colab.research.google.com/github/vishaljoshi24/DungeonsAndDragonsTurnClassification/blob/main/data_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA

# %%
from datasets import load_dataset
import pandas as pd

# %%
dataset = load_dataset("garrykuwanto/crd3_training_pairs", download_mode="force_redownload")
# Out:
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# crd3_training_pairs_no_llm.json: reconstructing file:   0%|          |  0.00B /  773MB
# crd3_training_pairs_no_llm.json: downloading bytes:           |  0.00B
# Generating train split:   0%|          | 0/2360582 [00:00<?, ? examples/s]

# %%
df = pd.DataFrame(dataset)

# %%
query = []
passage = []
for i in range(len(df.train[0:])):
  query.append(df.train[i]['query'])
  passage.append(df.train[i]['passage'])

df1 = pd.DataFrame({'context': query, 'current turn': passage})

# %%
df1
# Out:
#                                                    context  \
# 0        Dialogue context: MATT: And welcome to tonight...
# 1        Dialogue context: ZAC: Fantastical? MATT: Fant...
# 2        Dialogue context: MATT: Fantastical. ZAC: Test...
# 3        Dialogue context: ZAC: Testicular. MATT: It is...
# 4        Dialogue context: MATT: It is. It is a testicl...
# ...                                                    ...
# 2360577  Player says: Not continuing the song... (all l...
# 2360578                         Player says: Not Taliesin.
# 2360579                             Player says: Saturday.
# 2360580           Player says: It technically is tomorrow.
# 2360581               Player says: Starts tomorrow at 7pm!
#
#                                               current turn
# 0                                         ZAC: Testicular.
# 1        MATT: It is. It is a testicle episode of Criti...
# 2                                  ZAC: Cue cut to Ashley!
# ...

# %%
df2 = df1[(~df1['context'].str.startswith('Scene context:')) & (~df1['context'].str.startswith('Player says:'))]
# (~df1['current turn'].str.startswith('MATT:'))
# (~df1['current turn'].str.startswith('DM Responds:'))
# (~df1['current turn'].str.startswith('MATT Responds:')) &

# %%
df2
# Out:
#                                                    context  \
# 0        Dialogue context: MATT: And welcome to tonight...
# 1        Dialogue context: ZAC: Fantastical? MATT: Fant...
# 2        Dialogue context: MATT: Fantastical. ZAC: Test...
# 3        Dialogue context: ZAC: Testicular. MATT: It is...
# 4        Dialogue context: MATT: It is. It is a testicl...
# ...                                                    ...
# 2356317                                ALL says: Saturday.
# 2356318         MATT says: Sorry. Saturday. Friday. It's -
# 2356319         TALIESIN says: It technically is tomorrow.
# 2356320  MATT says: No, it's not tomorrow yet. Sorry. S...
# 2356321                LUCAS says: Starts tomorrow at 7pm!
#
#                                               current turn
# 0                                         ZAC: Testicular.
# 1        MATT: It is. It is a testicle episode of Criti...
# 2                                  ZAC: Cue cut to Ashley!
# ...

# %%
df3 = df2[(~df2['current turn'].str.startswith('AUDIENCE:'))]

# %%
df3
# Out:
#                                                    context  \
# 0        Dialogue context: MATT: And welcome to tonight...
# 1        Dialogue context: ZAC: Fantastical? MATT: Fant...
# 2        Dialogue context: MATT: Fantastical. ZAC: Test...
# 3        Dialogue context: ZAC: Testicular. MATT: It is...
# 4        Dialogue context: MATT: It is. It is a testicl...
# ...                                                    ...
# 2356317                                ALL says: Saturday.
# 2356318         MATT says: Sorry. Saturday. Friday. It's -
# 2356319         TALIESIN says: It technically is tomorrow.
# 2356320  MATT says: No, it's not tomorrow yet. Sorry. S...
# 2356321                LUCAS says: Starts tomorrow at 7pm!
#
#                                               current turn
# 0                                         ZAC: Testicular.
# 1        MATT: It is. It is a testicle episode of Criti...
# 2                                  ZAC: Cue cut to Ashley!
# ...

# %%
df4 = df3.drop_duplicates(subset=['context'], inplace=False)

# %%
df4
# Out:
#                                                    context  \
# 0        Dialogue context: MATT: And welcome to tonight...
# 1        Dialogue context: ZAC: Fantastical? MATT: Fant...
# 2        Dialogue context: MATT: Fantastical. ZAC: Test...
# 3        Dialogue context: ZAC: Testicular. MATT: It is...
# 4        Dialogue context: MATT: It is. It is a testicl...
# ...                                                    ...
# 2344063  Dialogue context: LIAM: Ja, but I rolled an 18...
# 2344065  Dialogue context: SAM: I'll just run over to J...
# 2344068  Dialogue context: MARISHA: They're all unconsc...
# 2352766  Dialogue context: TRAVIS: Who's with the burnt...
# 2353049  Dialogue context: in unison MARISHA TALIESIN: ...
#
#                                               current turn
# 0                                         ZAC: Testicular.
# 1        MATT: It is. It is a testicle episode of Criti...
# 2                                  ZAC: Cue cut to Ashley!
# ...

# %%
df5 = df4.drop_duplicates(subset=['current turn'], inplace=False)

# %%
df5
# Out:
#                                                    context  \
# 0        Dialogue context: MATT: And welcome to tonight...
# 1        Dialogue context: ZAC: Fantastical? MATT: Fant...
# 2        Dialogue context: MATT: Fantastical. ZAC: Test...
# 3        Dialogue context: ZAC: Testicular. MATT: It is...
# 4        Dialogue context: MATT: It is. It is a testicl...
# ...                                                    ...
# 2259502  MATT says: Gathering up the rest of those who ...
# 2259503  ASHLEY says: Sex. It's sex. It's lots of sex. ...
# 2259504  MATT says: All right. Well then, we're going t...
# 2259505  KHARY says: You know what, hold on! Take a bow...
# 2329854  Dialogue context: MATT: Hello everyone, welcom...
#
#                                               current turn
# 0                                         ZAC: Testicular.
# 1        MATT: It is. It is a testicle episode of Criti...
# 2                                  ZAC: Cue cut to Ashley!
# ...

# %%
df6 = df5[70:] #Point at which gameplay starts

# %%
df6
# Out:
#                                                    context  \
# 71       Dialogue context: ASHLEY: Yeah! MATT: By the w...
# 72       Dialogue context: MATT: By the way, thank you ...
# 73       Dialogue context: in unison SAM MATT: Includin...
# 74       Dialogue context: ASHLEY: I know! I didn't eve...
# 75       Dialogue context: TRAVIS: Mass panic, it's no ...
# ...                                                    ...
# 2259502  MATT says: Gathering up the rest of those who ...
# 2259503  ASHLEY says: Sex. It's sex. It's lots of sex. ...
# 2259504  MATT says: All right. Well then, we're going t...
# 2259505  KHARY says: You know what, hold on! Take a bow...
# 2329854  Dialogue context: MATT: Hello everyone, welcom...
#
#                                               current turn
# 71       ASHLEY: I know! I didn't even mean-- I just pu...
# 72                   TRAVIS: Mass panic, it's no big deal.
# 73       MATT: You're technically still here. And you k...
# ...

# %%
df6.to_json('cleaned_data.json', orient='split', compression='infer', index=True)

# %%
cleaned_data = pd.read_json('cleaned_data.json', orient='split', compression='infer')

# %%
cleaned_data
# Out:
#                                                    context  \
# 71       Dialogue context: ASHLEY: Yeah! MATT: By the w...
# 72       Dialogue context: MATT: By the way, thank you ...
# 73       Dialogue context: in unison SAM MATT: Includin...
# 74       Dialogue context: ASHLEY: I know! I didn't eve...
# 75       Dialogue context: TRAVIS: Mass panic, it's no ...
# ...                                                    ...
# 2259502  MATT says: Gathering up the rest of those who ...
# 2259503  ASHLEY says: Sex. It's sex. It's lots of sex. ...
# 2259504  MATT says: All right. Well then, we're going t...
# 2259505  KHARY says: You know what, hold on! Take a bow...
# 2329854  Dialogue context: MATT: Hello everyone, welcom...
#
#                                               current turn
# 71       ASHLEY: I know! I didn't even mean-- I just pu...
# 72                   TRAVIS: Mass panic, it's no big deal.
# 73       MATT: You're technically still here. And you k...
# ...

# %%
# unlabelled_trainset_draft = df1[113:513]

# filename = 'unlabelled_trainset_draft.xlsx'
# unlabelled_trainset_draft.to_excel(filename)

# %%
cleaned_data[284:]
# Out:
#                                                    context  \
# 382      Dialogue context: LAURA: Except for you, darli...
# 383      Dialogue context: MATT: It's very weird. You'r...
# 384      Dialogue context: TALIESIN: Bear-Percy is espe...
# 385      Dialogue context: MATT: Yeah. This giant rotun...
# 386      Dialogue context: LAURA: That is awkward. MATT...
# ...                                                    ...
# 2259502  MATT says: Gathering up the rest of those who ...
# 2259503  ASHLEY says: Sex. It's sex. It's lots of sex. ...
# 2259504  MATT says: All right. Well then, we're going t...
# 2259505  KHARY says: You know what, hold on! Take a bow...
# 2329854  Dialogue context: MATT: Hello everyone, welcom...
#
#                                               current turn
# 382      MATT: Yeah. This giant rotund Percy on his han...
# 383                                LAURA: That is awkward.
# 384      MATT: It's a very strange visual, and you're v...
# ...

# %%
cleaned_data[1939:2339]
# Out:
#                                                 context  \
# 2176  Dialogue context: ASHLEY: 26. MATT: 26, all ri...
# 2177  Dialogue context: MATT: 26, all right. What le...
# 2178  Dialogue context: ASHLEY: Five. Sorry, I did f...
# 2179  Dialogue context: MATT: 5th-level Healing Word...
# 2180  Dialogue context: SAM: Do it! ASHLEY: Shoot. O...
# ...                                                 ...
# 2626  Dialogue context: MARISHA: Can I go for a trip...
# 2627  Dialogue context: MATT: No, this is just a mel...
# 2628  Dialogue context: MARISHA: Fine, I'm going to ...
# 2629  Dialogue context: MATT: Okay! Roll damage. LIA...
# 2630  Dialogue context: LIAM: We've got the MVP over...
#
#                                            current turn
# 2176  MATT: 5th-level Healing Word. All righty. That...
# 2177                                        SAM: Do it!
# 2178         ASHLEY: Shoot. Okay, I'm not close to him.
# 2179  LIAM: Can you unleash some holy fire on any fu...
# ...

# %%
train_set = cleaned_data[1939:2339]

# %%
filename = 'refined_collaboration_codes.xlsx'
train_set.to_excel(filename)
